# %%
import pandas as pd
import numpy as np
from functions.input_collectors import display_widgets
df = pd.read_csv("cleaned_zomato.csv")
df["cuisines"] = df["cuisines"].apply(eval)

# %%
# Run application
if __name__ == '__main__':

    display_widgets(df)
# Out:
# SelectMultiple(description='Cuisine type: ', options=('North Indian', 'Chinese', 'South Indian', 'Fast Food', …
# SelectionRangeSlider(description='Price range: ', index=(0, 3), options=('$', '$$', '$$$', '$$$$'), value=('$'…
# FloatRangeSlider(value=(2.6, 4.2), description='Rating: ', max=5.0, min=1.8)
# Button(description='OK', style=ButtonStyle())
# Your preferences:
#         -- cuisine: ('North Indian',)
#         -- rating: (1.8, 5.0)
#         -- price: ('$', '$$$$')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5196722df85b65e12e86ddec4cfc4f1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5196722df85b65e12e86ddec4cfc4f1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5196722df85b65e12e86ddec4cfc4f1a = L.map(
#                 &quot;map_5196722df85b65e12e86ddec4cfc4f1a&quot;,
#                 {
#                     center: [12.978889, 77.591667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61f1f49835efd22bf91d108365b53540 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5196722df85b65e12e86ddec4cfc4f1a);
#
#
#             var marker_0d3bd41e10e957c49154be4f51930cd3 = L.marker(
#                 [12.939992144280321, 77.74565802329819],
#                 {}
#             ).addTo(map_5196722df85b65e12e86ddec4cfc4f1a);
#
#
#             var icon_1dec570125fec9abf3e61f8ed14e6e42 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d3bd41e10e957c49154be4f51930cd3.setIcon(icon_1dec570125fec9abf3e61f8ed14e6e42);
#
#
#         var popup_086ecbbf6ad398098190d703589ac2b9 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_7b8d2079bbe229f7b352f5f46c51d81a = $(`&lt;div id=&quot;html_7b8d2079bbe229f7b352f5f46c51d81a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;You are here!&lt;/b&gt;&lt;/div&gt;`)[0];
#             popup_086ecbbf6ad398098190d703589ac2b9.setContent(html_7b8d2079bbe229f7b352f5f46c51d81a);
#
#
#         marker_0d3bd41e10e957c49154be4f51930cd3.bindPopup(popup_086ecbbf6ad398098190d703589ac2b9)
#         ;
#
#
#
#
#             var marker_3a3c16ef72f8dbe52aca2971c0619463 = L.marker(
#                 [12.9602402, 77.7024023],
#                 {}
#             ).addTo(map_5196722df85b65e12e86ddec4cfc4f1a);
#
#
#             var icon_4caf250b2d29271c00abd20c54ce65f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a3c16ef72f8dbe52aca2971c0619463.setIcon(icon_4caf250b2d29271c00abd20c54ce65f7);
#
#
#         var popup_a8cbcfd6a3d8f336cac8fd998ea94252 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#             var html_a986015d97de9603fada05f4de429ef6 = $(`&lt;div id=&quot;html_a986015d97de9603fada05f4de429ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;AB&#x27;s - Absolute Barbecues&lt;/h4&gt;         &lt;b&gt;Address:&lt;/b&gt; 90/4, 3rd Floor, Outer Ring Road, Munnekollaly Village, Marathahalli, Bangalore&lt;br&gt;         &lt;div style=&quot;white-space: nowrap;overflow: hidden;text-overflow: ellipsis;&quot;&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=https://www.zomato.com/bangalore/abs-absolute-barbecues-marathahalli?context=&gt;https://www.zomato.com/bangalore/abs-absolute-barbecues-marathahalli?context=&lt;/a&gt;&lt;/div&gt;         &lt;b&gt;Phone number(s):&lt;/b&gt; 080 49652574&lt;br&gt;         &lt;b&gt;Rating:&lt;/b&gt; 4.8/5 (12121 votes) &lt;br&gt;         &lt;b&gt;Cuisine type:&lt;/b&gt; European, Mediterranean, North Indian, BBQ&lt;br&gt;         &lt;b&gt;Price:&lt;/b&gt; $$$$&lt;/div&gt;`)[0];
#             popup_a8cbcfd6a3d8f336cac8fd998ea94252.setContent(html_a986015d97de9603fada05f4de429ef6);
#
#
#         marker_3a3c16ef72f8dbe52aca2971c0619463.bindPopup(popup_a8cbcfd6a3d8f336cac8fd998ea94252)
#         ;
#
#
#
#
#             marker_3a3c16ef72f8dbe52aca2971c0619463.bindTooltip(
#                 `&lt;div&gt;
#
#                 &lt;b&gt;TOP 1: &lt;/b&gt;&lt;i&gt;AB&#x27;s - Absolute Barbecues&lt;/i&gt;.
#                 You will get there on foot in 65 minutes.
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_427b21c67ddb27f883b7f2250
