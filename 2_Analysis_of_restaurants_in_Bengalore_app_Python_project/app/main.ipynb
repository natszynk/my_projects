# %%
import pandas as pd
import streamlit as st
import numpy as np
from functions.input_collectors import display_widgets, cuisines_list
from functions.application_runner import run_application
df = pd.read_csv("cleaned_zomato.csv")
df["cuisines"] = df["cuisines"].apply(eval)

# %%
# Run application
if __name__ == '__main__':

    display_widgets(df)
# Out:
# SelectMultiple(description='Cuisine type: ', options=('North Indian', 'Chinese', 'South Indian', 'Fast Food', …
# SelectionRangeSlider(description='Price range: ', index=(0, 3), options=('$', '$$', '$$$', '$$$$'), value=('$'…
# FloatRangeSlider(value=(2.6, 4.2), description='Rating: ', max=5.0, min=1.8)
# Checkbox(value=False, description='Include new restaurants: ')
# Button(description='OK', style=ButtonStyle())
# Output()
# Your preferences:
#         -- cuisine: ('North Indian', 'Chinese', 'South Indian')
#         -- rating: (2.6, 5.0)
#         -- price: ('$', '$$')
#         -- include new restaurants: True
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce4294fc93407e5338519a616fc43e75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce4294fc93407e5338519a616fc43e75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ce4294fc93407e5338519a616fc43e75 = L.map(
#                 &quot;map_ce4294fc93407e5338519a616fc43e75&quot;,
#                 {
#                     center: [12.978889, 77.591667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4db705900de7e7ea57ee8936e48b15a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce4294fc93407e5338519a616fc43e75);
#
#
#             var marker_dcf13c1e27ec9f5f175237f60a0c9d9b = L.marker(
#                 [12.872423385111038, 77.52639655200971],
#                 {}
#             ).addTo(map_ce4294fc93407e5338519a616fc43e75);
#
#
#             var icon_6861bf90305d805ade85c079fabf5167 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dcf13c1e27ec9f5f175237f60a0c9d9b.setIcon(icon_6861bf90305d805ade85c079fabf5167);
#
#
#         var popup_75e58ef597d74d4f836def16c418383f = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var html_79fbd18e1149c3ce2b7ef9ad9aec61b5 = $(`&lt;div id=&quot;html_79fbd18e1149c3ce2b7ef9ad9aec61b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;You are here!&lt;/b&gt;&lt;/div&gt;`)[0];
#             popup_75e58ef597d74d4f836def16c418383f.setContent(html_79fbd18e1149c3ce2b7ef9ad9aec61b5);
#
#
#         marker_dcf13c1e27ec9f5f175237f60a0c9d9b.bindPopup(popup_75e58ef597d74d4f836def16c418383f)
#         ;
#
#
#
#
#             var marker_ad64cacc211927cd47cc08a362d1cec6 = L.marker(
#                 [12.9427211, 77.5732621],
#                 {}
#             ).addTo(map_ce4294fc93407e5338519a616fc43e75);
#
#
#             var icon_ff1c92670ea7df36987413f9935b9489 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-cutlery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad64cacc211927cd47cc08a362d1cec6.setIcon(icon_ff1c92670ea7df36987413f9935b9489);
#
#
#         var popup_41540ba60b2e57b5a0c5eb91d31cdd73 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#             var html_19f176ff4776bddfc3a2d8c5fbee9d0d = $(`&lt;div id=&quot;html_19f176ff4776bddfc3a2d8c5fbee9d0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;h4&gt;Brahmin&#x27;s Coffee Bar&lt;/h4&gt;         &lt;b&gt;Address:&lt;/b&gt; Ranga Rao Road, Near Shankar Mutt, Shankarapura, Near Basavanagudi, Bangalore&lt;br&gt;         &lt;div style=&quot;white-space: nowrap;overflow: hidden;text-overflow: ellipsis;&quot;&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=https://www.zomato.com/bangalore/brahmins-coffee-bar-basavanagudi?context=&gt;https://www.zomato.com/bangalore/brahmins-coffee-bar-basavanagudi?context=&lt;/a&gt;&lt;/div&gt;         &lt;b&gt;Phone number(s):&lt;/b&gt; +91 9845030234&lt;br&gt;         &lt;b&gt;Rating:&lt;/b&gt; 4.8/5 (2679 votes) &lt;br&gt;         &lt;b&gt;Cuisine type:&lt;/b&gt; South Indian&lt;br&gt;         &lt;b&gt;Price:&lt;/b&gt; $&lt;/div&gt;`)[0];
#             popup_41540ba60b2e57b5a0c5eb91d31cdd73.setContent(html_19f176ff4776bddfc3a2d8c5fbee9d0d);
#
#
#         marker_ad64cacc211927cd47cc08a362d1cec6.bindPopup(popup_41540ba60b2e57b5a0c5eb91d31cdd73)
#         ;
#
#
#
#
#             marker_ad64cacc211927cd47cc08a362d1cec6.bindTooltip(
#                 `&lt;div&gt;
#
#                 &lt;b&gt;TOP 1: &lt;/b&gt;&lt;i&gt;Brahmin&#x27;s Coffee Bar&lt;/i&gt;.
#                 You will get there on foot in 116 minutes.
#                  &lt;/div&gt;`,
#                 {&quot;st
